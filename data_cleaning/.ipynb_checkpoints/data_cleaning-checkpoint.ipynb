# %%
import pandas as pd

# %%
df = pd.read_csv('./../feature_complete_final_data.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Unnamed: 0_x            name  \
# 0             0           0             0    Drag Me Down
# 1             1           1             1  Balam Pichkari
# 2             2           2             2           Ilahi
# 3             3           3             3   Badtameez Dil
# 4             4           4             4          Kabira
#
#                        id  Unnamed: 0_y  danceability  energy  key  loudness  \
# 0  3pDek256ZgaPcii9t9o4dv             0         0.711   0.729    8    -4.462
# 1  18e3XXYCv4Tx8uUl1mP3CN             1         0.732   0.944    0    -4.115
# 2  5cgKosPPj5Cs9a2JQufUc1             2         0.593   0.967    9    -5.767
# 3  4eu27jAU2bbnyHUC3G75U8             3         0.806   0.932    2    -2.228
# 4  3jJ5HgLRNydtLRghjWVaCG             4         0.611   0.612    2    -7.978
#
#    ...    tempo            type                                   uri  \
# 0  ...  138.099  audio_features  spotify:track:3pDek256ZgaPcii9t9o4dv
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 0_x', 'name', 'id',
#        'Unnamed: 0_y', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'end_time', 'ms_played',
#        'artist_name'],
#       dtype='object')

# %%
df = df.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 0_x', 'Unnamed: 0_y', 'type', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
df.head()
# Out:
#              name                      id  danceability  energy  key  \
# 0    Drag Me Down  3pDek256ZgaPcii9t9o4dv         0.711   0.729    8
# 1  Balam Pichkari  18e3XXYCv4Tx8uUl1mP3CN         0.732   0.944    0
# 2           Ilahi  5cgKosPPj5Cs9a2JQufUc1         0.593   0.967    9
# 3   Badtameez Dil  4eu27jAU2bbnyHUC3G75U8         0.806   0.932    2
# 4          Kabira  3jJ5HgLRNydtLRghjWVaCG         0.611   0.612    2
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -4.462     1       0.0822        0.0542          0.000000    0.0822
# 1    -4.115     1       0.0900        0.2090          0.000000    0.4010
# 2    -5.767     1       0.0907        0.1660          0.000025    0.1050
# 3    -2.228     0       0.0684        0.2400          0.000000    0.2160
# 4    -7.978     1       0.1140        0.4410          0.000000    0.1800
#
#    valence    tempo          end_time  ms_played    artist_name
# ...

# %%
df.shape
# Out:
# (1332, 16)

# %%
#ensuring no cells are empty
df.isnull().sum()
# Out:
# name                0
# id                  0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# end_time            0
# ms_played           0
# artist_name         0
# dtype: int64

# %%
df.dtypes
# Out:
# name                 object
# id                   object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# end_time             object
# ms_played             int64
# artist_name          object
# dtype: object

# %%
df.max(axis = 0)
# Out:
# name                         thank u, next
# id                  7zgXFtMLaRnDweNdVWGpVF
# danceability                         0.971
# energy                               0.998
# key                                     11
# loudness                             0.107
# mode                                     1
# speechiness                          0.519
# acousticness                         0.995
# instrumentalness                     0.978
# liveness                             0.937
# valence                              0.982
# tempo                              200.155
# end_time                  2024-03-16 19:23
# ms_played                         10676506
# artist_name                       vaultboy
# dtype: object

# %%
df.min(axis = 0)
# Out:
# name                        1-800-273-8255
# id                  0066u0Nc8LLFYvln3BmBJd
# danceability                        0.0629
# energy                             0.00112
# key                                      0
# loudness                           -44.945
# mode                                     0
# speechiness                         0.0232
# acousticness                      0.000006
# instrumentalness                       0.0
# liveness                            0.0193
# valence                             0.0263
# tempo                               36.189
# end_time                  2023-03-17 05:24
# ms_played                                0
# artist_name                       24kGoldn
# dtype: object

# %%
df.to_csv('./../final_cleaned_data.csv')

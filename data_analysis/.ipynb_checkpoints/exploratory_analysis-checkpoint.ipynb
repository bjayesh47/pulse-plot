# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calplot

# %%
my_streams = pd.read_csv('../song_streaming_history.csv')
my_streams = my_streams.drop(columns = ['Unnamed: 0'])

# %%
my_streams.head()
# Out:
#              name                      id  danceability  energy  key  \
# 0    Drag Me Down  3pDek256ZgaPcii9t9o4dv         0.711   0.729    8
# 1    Drag Me Down  3pDek256ZgaPcii9t9o4dv         0.711   0.729    8
# 2    Drag Me Down  3pDek256ZgaPcii9t9o4dv         0.711   0.729    8
# 3  Balam Pichkari  18e3XXYCv4Tx8uUl1mP3CN         0.732   0.944    0
# 4  Balam Pichkari  18e3XXYCv4Tx8uUl1mP3CN         0.732   0.944    0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -4.462     1       0.0822        0.0542               0.0    0.0822
# 1    -4.462     1       0.0822        0.0542               0.0    0.0822
# 2    -4.462     1       0.0822        0.0542               0.0    0.0822
# 3    -4.115     1       0.0900        0.2090               0.0    0.4010
# 4    -4.115     1       0.0900        0.2090               0.0    0.4010
#
#    valence    tempo  duration_ms    artist_name          end_time  ms_played  \
# 0    0.363  138.099       189226  One Direction  2023-03-14 12:36     133758
# 1    0.363  138.099       189226  One Direction  2023-09-09 18:37     192120
# 2    0.363  138.099       189226  One Direction  2023-11-06 20:12      56690
# 3    0.957  120.020       288903         Pritam  2023-03-17 05:13       1184
# 4    0.957  120.020       288903         Pritam  2023-04-09 14:19     117446
#
#    mins_played
# 0         2.23
# 1         3.20
# 2         0.94
# 3         0.02
# 4         1.96

# %%
my_streams['mins_played'] = my_streams.apply(lambda x: round(x['ms_played']/60000, 2), axis = 1)
my_streams['date'] = my_streams.apply(lambda x: pd.to_datetime(x['end_time'][:10], format = '%Y-%m-%d'), axis = 1)
my_streams.head()
# Out:
#              name                      id  danceability  energy  key  \
# 0    Drag Me Down  3pDek256ZgaPcii9t9o4dv         0.711   0.729    8
# 1    Drag Me Down  3pDek256ZgaPcii9t9o4dv         0.711   0.729    8
# 2    Drag Me Down  3pDek256ZgaPcii9t9o4dv         0.711   0.729    8
# 3  Balam Pichkari  18e3XXYCv4Tx8uUl1mP3CN         0.732   0.944    0
# 4  Balam Pichkari  18e3XXYCv4Tx8uUl1mP3CN         0.732   0.944    0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -4.462     1       0.0822        0.0542               0.0    0.0822
# 1    -4.462     1       0.0822        0.0542               0.0    0.0822
# 2    -4.462     1       0.0822        0.0542               0.0    0.0822
# 3    -4.115     1       0.0900        0.2090               0.0    0.4010
# 4    -4.115     1       0.0900        0.2090               0.0    0.4010
#
#    valence    tempo  duration_ms    artist_name          end_time  ms_played  \
# 0    0.363  138.099       189226  One Direction  2023-03-14 12:36     133758
# 1    0.363  138.099       189226  One Direction  2023-09-09 18:37     192120
# 2    0.363  138.099       189226  One Direction  2023-11-06 20:12      56690
# 3    0.957  120.020       288903         Pritam  2023-03-17 05:13       1184
# 4    0.957  120.020       288903         Pritam  2023-04-09 14:19     117446
#
#    mins_played       date
# 0         2.23 2023-03-14
# 1         3.20 2023-09-09
# 2         0.94 2023-11-06
# 3         0.02 2023-03-17
# 4         1.96 2023-04-09

# %%
daily_length = my_streams.groupby('date', as_index=True).sum()
# Out:
#                                                          name  \
# date
# 2023-03-14                                       Drag Me Down
# 2023-03-17  Balam PichkariIlahiBadtameez DilBadtameez DilK...
# 2023-03-22  Happy NowMood (Remix) feat. Justin Bieber, J B...
# 2023-03-24                     Ghodey Pe Sawaar (From "Qala")
# 2023-03-25  KabiraCharacter Dheela 2.0 (From "Shehzada")Gh...
#
#                                                            id  danceability  \
# date
# 2023-03-14                             3pDek256ZgaPcii9t9o4dv         0.711
# 2023-03-17  18e3XXYCv4Tx8uUl1mP3CN5cgKosPPj5Cs9a2JQufUc14e...        28.894
# 2023-03-22  4keoy2fqgwGnbWlm3ZVZFa6FuGJB290AQMAHTfjOYVaK5G...        42.068
# 2023-03-24                             1a8w8nlIyIhE2W1HIayKnl         0.777
# 2023-03-25  3jJ5HgLRNydtLRghjWVaCG24AfLjMMgO8AjhQw8l7y1L1a...         9.644
#
#             energy  key  loudness  mode  speechiness  acousticness  \
# date
# 2023-03-14   0.729    8    -4.462     1       0.0822      0.054200
# 2023-03-17  32.253  250  -278.668    31       4.0692     13.153042
# 2023-03-22  41.993  339  -386.639    37       4.6998     18.753790
# 2023-03-24   0.481    3    -6.127     1       0.0274      0.794000
# 2023-03-25   8.935   86   -93.011     7       0.9562      6.682400
#
#             instrumentalness  liveness  valence     tempo  duration_ms  \
# date
# 2023-03-14          0.000000    0.0822    0.363   138.099       189226
# 2023-03-17          1.296830    7.3012   26.796  5375.339     10063297
# 2023-03-22          0.127757   11.6168   34.500  7117.982     12937593
# 2023-03-24          0.000042    0.2650    0.814   102.003       193832
# 2023-03-25          0.020240    2.0842    7.201  1565.506      3338851
#
#                                                   artist_name  \
# date
# 2023-03-14                                      One Direction
# 2023-03-17  PritamPritamPritamPritamPritamPritamPritamPrit...
# 2023-03-22  Zedd24kGoldnHailee SteinfeldPritamImagine Drag...
# 2023-03-24                                       Amit Trivedi
# 2023-03-25  PritamPritamAmit TrivediAnkit TiwariKingTanish...
#
#                                                      end_time  ms_played  \
# date
# 2023-03-14                                   2023-03-14 12:36     133758
# 2023-03-17  2023-03-17 05:132023-03-17 05:132023-03-17 05:...    4155117
# 2023-03-22  2023-03-22 06:142023-03-22 10:312023-03-22 06:...    5969020
# 2023-03-24                                   2023-03-24 19:10      10240
# 2023-03-25  2023-03-25 18:302023-03-25 08:582023-03-25 08:...    1183988
#
#             mins_played
# date
# 2023-03-14         2.23
# 2023-03-17        69.24
# 2023-03-22        99.46
# 2023-03-24         0.17
# 2023-03-25        19.75

# %%
idx = pd.DataFrame(pd.date_range(min(my_streams.date), max(my_streams.date)), columns = ['date'])
idx['date'] = my_streams.apply(lambda x: pd.to_datetime(x['date'], format = '%Y-%m-%d'), axis = 1)

new_daily_length = pd.merge(idx, daily_length, how = 'left', left_on = 'date', right_on = 'date', copy = False)
new_daily_length = new_daily_length.filter(['date', 'mins_played'])
new_daily_length.head()
# Out:
#         date  mins_played
# 0 2023-03-14         2.23
# 1 2023-09-09       233.62
# 2 2023-11-06        74.03
# 3 2023-03-17        69.24
# 4 2023-04-09        63.06

# %%
new_daily_length.index = new_daily_length.date
new_daily_length = new_daily_length.drop(columns=['date'])
new_daily_length.head()
# Out:
#             mins_played
# date
# 2023-03-14         2.23
# 2023-09-09       233.62
# 2023-11-06        74.03
# 2023-03-17        69.24
# 2023-04-09        63.06

# %%
new_daily_length = new_daily_length.squeeze()

# %%
calplot.calplot(new_daily_length, figsize=(20, 10), suptitle='My Streaming History', cmap='Spectral')
# Out:
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# (<Figure size 2000x1000 with 3 Axes>,
#  array([<Axes: ylabel='2023'>, <Axes: ylabel='2024'>], dtype=object))
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.

# %%
artist_df = my_streams.filter(['artist_name', 'name', 'ms_played', 'mins_played'])
artist_length = artist_df.groupby('artist_name',as_index=False).sum()
artist_song_cnt = artist_df.groupby('artist_name',as_index=False).agg({'name': 'nunique'})
artist_song_cnt
# Out:
#              artist_name  name
# 0               24kGoldn     2
# 1    5 Seconds of Summer     2
# 2                50 Cent     1
# 3              7Bantai'Z     1
# 4            A.R. Rahman    17
# ..                   ...   ...
# 509         Zeus X Crona     1
# 510         benny blanco     1
# 511                 fun.     1
# 512                  mgk    11
# 513             vaultboy     1
#
# [514 rows x 2 columns]

# %%
artist_final_df = pd.merge(artist_length, artist_song_cnt, how='left', on='artist_name', copy=True)
artist_final_df.rename(columns={'name_y':'unique_track_number'},inplace=True)
artist_final_df = artist_final_df.drop(columns = ['name_x'])

# %%
max_time = artist_final_df.sort_values(by=['ms_played'])
max_time.tail()
# Out:
#             artist_name  ms_played  mins_played  unique_track_number
# 494  Walk off the Earth   13924970       231.97                    3
# 69              Badshah   15463853       257.82                   26
# 392        Sachin-Jigar   21830573       363.75                   12
# 61               Avicii   22825548       380.36                   12
# 350              Pritam  126386005      2106.52                   97

# %%
most_heard_30 = max_time.tail(10)

# %%
plt.rcParams["figure.figsize"] = (10,10)
sns.barplot(y = most_heard_30['artist_name'], x = most_heard_30['mins_played'], palette='rocket_r')
plt.title('Top 10 Artist heard')
plt.show()
# Out:
# /tmp/ipykernel_137076/2212246149.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = most_heard_30['artist_name'], x = most_heard_30['mins_played'], palette='rocket_r')
